# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
from sklearn.svm import OneClassSVM
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, classification_report

# %%
file_p = 'dataset.csv'
data = pd.read_csv(file_p)
data
# Out:
#        src_port  dst_port  protocol  flow_duration  flow_byts_s  flow_pkts_s  \
# 0         36272        80        17      3643793.0  1462.761469     1.372196
# 1         38732        80        17      3644007.0  3217.886244     3.018655
# 2         39137        80        17      3643888.0  3217.991332     3.018754
# 3         50835        80        17      3643754.0  3218.109675     3.018865
# 4         38762        80        17      3644320.0  3217.609870     3.018396
# ...         ...       ...       ...            ...          ...          ...
# 27171     32984        80        17      1695108.0  2515.473940     2.359732
# 27172     44313        80        17       844430.0  2524.780029     2.368462
# 27173     47854        80        17      1706398.0  2498.830871     2.344119
# 27174     49410        80        17       639746.0  3332.572615     3.126241
# 27175     52717        80        17       664587.0  3208.007379     3.009388
#
#        fwd_pkts_s  bwd_pkts_s  tot_fwd_pkts  tot_bwd_pkts  ...  \
# 0        1.372196         0.0             5             0  ...
# 1        3.018655         0.0            11             0  ...
# 2        3.018754         0.0            11             0  ...
# 3        3.018865         0.0            11             0  ...
# 4        3.018396         0.0            11             0  ...
# ...           ...         ...           ...           ...  ...
# 27171    2.359732         0.0             4             0  ...
# 27172    2.368462         0.0             2             0  ...
# 27173    2.344119         0.0             4             0  ...
# 27174    3.126241         0.0             2             0  ...
# 27175    3.009388         0.0             2             0  ...
#
#        bwd_pkts_b_avg  fwd_blk_rate_avg  bwd_blk_rate_avg  fwd_seg_size_avg  \
# 0                 0.0          0.000000               0.0            1066.0
# 1                 0.0       3091.102734               0.0            1066.0
# 2                 0.0       3091.203681               0.0            1066.0
# 3                 0.0       3091.317361               0.0            1066.0
# 4                 0.0       3090.837248               0.0            1066.0
# ...               ...               ...               ...               ...
# 27171             0.0          0.000000               0.0            1066.0
# 27172             0.0          0.000000               0.0            1066.0
# 27173             0.0       2400.377872               0.0            1066.0
# 27174             0.0          0.000000               0.0            1066.0
# 27175             0.0          0.000000               0.0            1066.0
#
#        bwd_seg_size_avg  cwe_flag_count  subflow_fwd_pkts  subflow_bwd_pkts  \
# 0                   0.0               0                 5                 0
# 1                   0.0               0                11                 0
# 2                   0.0               0                11                 0
# 3                   0.0               0                11                 0
# 4                   0.0               0                11                 0
# ...                 ...             ...               ...               ...
# 27171               0.0               0                 4                 0
# 27172               0.0               0                 2                 0
# 27173               0.0               0                 4                 0
# 27174               0.0               0                 2                 0
# 27175               0.0               0                 2                 0
#
#        subflow_fwd_byts  subflow_bwd_byts
# 0                  5330                 0
# 1                 11726                 0
# 2                 11726                 0
# 3                 11726                 0
# 4                 11726                 0
# ...                 ...               ...
# 27171              4264                 0
# 27172              2132                 0
# 27173              4264                 0
# 27174              2132                 0
# 27175              2132                 0
#
# [27176 rows x 79 columns]

# %%
clf = OneClassSVM(kernel='linear', nu=0.5) # nu = 0.5 means we are allowing the svm model to have about 50% of the data as outliears
clf.fit(data)
# Out:
# OneClassSVM(kernel='linear')

# %%
new_p = 'output.csv'
output_data = pd.read_csv(new_p)
output_data
# Out:
#          src_port  dst_port     protocol  flow_duration    flow_byts_s  \
# 0    41203.729499        80     8.578710   3.448745e+01      25.919016
# 1    61586.873321        80     8.164779   4.652373e+00     122.172735
# 2    53469.455784        80     7.311161   3.293322e+06  815420.232682
# 3    38291.975035        80     8.508491   5.280637e-02      50.109339
# 4    59663.242734        80    70.484107   2.447035e+01       0.072178
# ..            ...       ...          ...            ...            ...
# 995  51171.962945        80    19.961565   8.313054e+01      49.624131
# 996  33932.239682        80    31.104025   2.010618e-01       0.052087
# 997  48480.797658        80    56.712663   8.283850e+01      84.800553
# 998  49354.637952        80  5434.914149   8.698668e+01      57.205947
# 999  38858.957770        80     9.144992   7.062828e+00       6.770849
#
#       flow_pkts_s    fwd_pkts_s    bwd_pkts_s  tot_fwd_pkts  tot_bwd_pkts  \
# 0    9.848214e+07  30191.686776  8.483466e+07  1.067847e+06   1646.869153
# 1    5.427086e+01     41.886991  4.436981e+01  7.733534e-02     81.594940
# 2    4.044721e+01     44.277253  3.910023e+01  1.049334e+01     91.518014
# 3    7.219876e-02     47.385727  3.573217e-02  5.887592e+01     77.801372
# 4    6.390067e-02      0.062067  8.263453e+01  5.419693e+01      3.856440
# ..            ...           ...           ...           ...           ...
# 995  6.035497e+01     10.267672  3.206330e+00  2.429942e+01     35.816803
# 996  6.329830e-02     78.269142  5.969630e+01  5.677098e+01     40.629446
# 997  7.547337e+01     57.070290  5.111333e+01  5.002453e+01      0.056587
# 998  4.207729e+01     50.573089  8.494842e-02  8.853446e+01     53.642482
# 999  1.333042e+06     91.250247  5.691614e-02  4.876359e+01     45.041347
#
#      ...  bwd_pkts_b_avg  fwd_blk_rate_avg  bwd_blk_rate_avg  \
# 0    ...               0      66719.018627                 0
# 1    ...               0      21647.937849                 0
# 2    ...               0         45.729645                 0
# 3    ...               0          0.004477                 0
# 4    ...               0          0.020787                 0
# ..   ...             ...               ...               ...
# 995  ...               0         50.441608                 0
# 996  ...               0          0.110558                 0
# 997  ...               0          0.047445                 0
# 998  ...               0          8.225058                 0
# 999  ...               0       9686.202999                 0
#
#      fwd_seg_size_avg  bwd_seg_size_avg  cwe_flag_count  subflow_fwd_pkts  \
# 0                1066                 0               0         67.919236
# 1                1066                 0               0         56.633207
# 2                1066                 0               0          3.263235
# 3                1066                 0               0          0.102340
# 4                1066                 0               0      12046.078910
# ..                ...               ...             ...               ...
# 995              1066                 0               0         42.872740
# 996              1066                 0               0         43.344131
# 997              1066                 0               0        185.998724
# 998              1066                 0               0       9355.635576
# 999              1066                 0               0         10.468593
#
#      subflow_bwd_pkts  subflow_fwd_byts  subflow_bwd_byts
# 0                   0          0.080436                 0
# 1                   0          0.092703                 0
# 2                   0        265.241923                 0
# 3                   0      44772.092630                 0
# 4                   0          0.047616                 0
# ..                ...               ...               ...
# 995                 0         51.089077                 0
# 996                 0         41.134528                 0
# 997                 0       4590.289630                 0
# 998                 0         48.754964                 0
# 999                 0         35.450969                 0
#
# [1000 rows x 79 columns]

# %%
predictions = clf.predict(output_data)

output_data['prediction'] = predictions

# %%
#pca = PCA(n_components=2)
#new_data_reduced = pca.fit_transform(output_data)

#plt.figure(figsize=(10, 6))
#plt.scatter(new_data_reduced[predictions == -1, 0], new_data_reduced[predictions == -1, 1], s=50, c='red', label='Outliers')
#plt.scatter(new_data_reduced[predictions == 1, 0], new_data_reduced[predictions == 1, 1], s=50, c='blue', label='Inliers')
#plt.title("OneClassSVM Predictions")
#plt.xlabel("PCA Feature 1")
#plt.ylabel("PCA Feature 2")
#plt.legend()
#plt.show()

# %%
num_inliers_data = np.sum(predictions == 1)

percentage_inliers_data = (num_inliers_data / len(predictions)) * 100


print(f"Percentage of inliers for the output data: {percentage_inliers_data:.2f}%")
# Out:
# Percentage of inliers for the output data: 16.60%

# %%
random_20_percent = data.sample(frac=0.2, random_state=42)  # Set random_state for reproducibility

# Remove the selected 20% from the original DataFrame
data_2 = data.drop(random_20_percent.index)

clf1 = OneClassSVM(kernel='linear', nu=0.5)
clf1.fit(data)

predictions1 = clf1.predict(data_2)
data_2['prediction'] = predictions1
num_inliers_out = np.sum(predictions1 == 1)
percentage_inliers_out = (num_inliers_out / len(predictions1)) * 100
print(f"Percentage of inliers for the data it self: {percentage_inliers_out:.2f}%")
# Out:
# Percentage of inliers for the data it self: 49.98%

# %%
def res(data,new_data,nu1):
  clf = OneClassSVM(kernel='linear', nu=nu1)
  clf.fit(data)

  predictions = clf.predict(new_data)
  new_data['prediction'] = predictions

  pca = PCA(n_components=2)
  new_data_reduced = pca.fit_transform(new_data)

  num_inliers = np.sum(predictions == 1)
  percentage_inliers = (num_inliers / len(predictions)) * 100

  return percentage_inliers

# %%
nu = [0.005,0.01,0.05,0.1,0.15,0.2,0.25]
#percent = []
#for i in range(len(nu)):
#  output_data = pd.read_csv(new_p)
#  a = res(data,output_data,nu[i])
#  percent.append(a)

# %%
#plt.plot(nu, percent, marker='o', linestyle='-')
#plt.xlabel('nu')
#plt.ylabel('Percent')
#plt.title('Percent vs nu')
#plt.grid(True)
#plt.show()
